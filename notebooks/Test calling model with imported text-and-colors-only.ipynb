# %%
import sys 

from IPython import display

sys.path.append("..")
sys.path.append("../utlities")
from utlities.query_and_display import get_and_show_most_similar_emails_html

# %%
display.display(
    display.HTML(
        get_and_show_most_similar_emails_html("42_days_winback_fertility", "text-and-colors-only")
    )
)
# Out:
#     <div class="row" style="display: flex; justify-content: space-between; align-items: flex-start;">
#         <div style="display: flex; flex-direction: column; align-items: center; width: 25%;">
#             <h2>Reference email</h2>
#             <div>
#             <div style="width: 90%; height: 600px; overflow: hidden;">
#                 <img src="data:image/jpeg;base64,..." style="width: 100%;">
#             </div>
#         </div>
#             <br><br>text:<br> - circular-framed logo<br> - announcement banner style<br> - sans-serif simplicity<br> - centered alignment<br> - minimal text density<br> - breathing space<br> - understated typography<br><br>color_scheme:<br> - soothing pastels<br> - medical wellness palette<br> - mint freshness<br> - gentle gradients<br> - airy lightness<br> - spa-like tranquility<br> - feminine softness
#             </div>
#         <div style="display: flex; flex-direction: column; align-items: center; width: 75%;">
# ...

# %%
display.display(
    display.HTML(
        get_and_show_most_similar_emails_html("venmo-1", "layout-and-text-only-2")
    )
)
# Out:
#     <div class="row" style="display: flex; justify-content: space-between; align-items: flex-start;">
#         <div style="display: flex; flex-direction: column; align-items: center; width: 25%;">
#             <h2>Reference email</h2>
#             <div>
#             <div style="width: 90%; height: 600px; overflow: hidden;">
#                 <img src="data:image/jpeg;base64,..." style="width: 100%;">
#             </div>
#         </div>
# ...

# %%
display.display(
    display.HTML(
        get_and_show_most_similar_emails_html("image6", "layout-and-text-only-2")
    )
)
# Out:
#     <div class="row" style="display: flex; justify-content: space-between; align-items: flex-start;">
#         <div style="display: flex; flex-direction: column; align-items: center; width: 25%;">
#             <h2>Reference email</h2>
#             <div>
#             <div style="width: 90%; height: 600px; overflow: hidden;">
#                 <img src="data:image/jpeg;base64,..." style="width: 100%;">
#             </div>
#         </div>
# ...

# %%
display.display(
    display.HTML(
        get_and_show_most_similar_emails_html("Screenshot_2024-04-18_at_11_02_41_AM", "layout-and-text-only-2")
    )
)
# Out:
#     <div class="row" style="display: flex; justify-content: space-between; align-items: flex-start;">
#         <div style="display: flex; flex-direction: column; align-items: center; width: 25%;">
#             <h2>Reference email</h2>
#             <div>
#             <div style="width: 90%; height: 600px; overflow: hidden;">
#                 <img src="data:image/jpeg;base64,..." style="width: 100%;">
#             </div>
#         </div>
# ...

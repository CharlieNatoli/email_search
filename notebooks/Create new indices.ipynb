# %%
import sys 

from IPython import display

sys.path.append("..")
sys.path.append("../utlities")
from utlities.query_and_display import get_and_show_most_similar_emails_html
from utlities.pinecone_index_utilities import create_index, get_embeddings_and_upsert, create_index
from utlities.text_tags_from_images import create_image_tags_full_dataset, create_image_tags_single_image

# %%
SYSTEM_PROMPT = """You are a helpful bot who provides detailed tags for professioanlly done marketing emails. 
First, describe the header area of an email in 1 sentence (up to 15 words). Marketing emails usually contain multiple topics / components.
We only care about the first one, a.k.a. what is "above the fold" at the top of the email. 

Next, list out the tags for each theme area. 
These tags will be used to help professional email marketers search an inspiration database to discover the emails that are most relevant to their query. 
It's important that you think like a professional marketing designer when writing these tags. 
For each of the following categories, please return 6-10 tags. related to themes you see in the header area. 

Please AVOID any tags that are generic to many well-made marketing emails. 
These are not helpful, as they don't distingish the email from other ones. 
Some examples of overly generic tags to avoid are things like "Clean Spacing", "Clear Hierarchy", "Mobile-Optimized", or "Professional". We can assume that all emails in our dataset are like this. 

Return the output as a json dictionary like so:
{
    "header_area_description": "...", # 1 sentence, up to 15 words describing the layout in words.
    "layout": ["First Tag", "Second", ...],  # 10-15 tags. repeat the description as tags.
    "brand_style": [...], # 6 tags. what words best represent the brand style/voice of this email? What's the art style? 
    "text": [...],  # 6 tags.what kinds of fonts and text formats do they use, what techniques are used in laying out text?
    "color_scheme": [...], # 6 tags. how would you describe the vibe of color scheme? (don't say specific colors, though) 
}
"""

# %%
b = create_image_tags_full_dataset(
    index_name='email-header-focus-fewer-tags',
    data_extraction_prompt=SYSTEM_PROMPT, 
    tags_to_ignore='header_area_description',
    batch_size=80,
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 3
#       1 b = create_image_tags_full_dataset(
#       2     index_name='email-header-focus-fewer-tags',
# ----> 3     data_extraction_prompt=SYSTEM_PROMPT,
#       4     tags_to_ignore='header_area_description',
#       5     batch_size=80,
#       6 )
#
# NameError: name 'SYSTEM_PROMPT' is not defined

# %%
create_index('email-header-focus-fewer-tags')
get_embeddings_and_upsert('email-header-focus-fewer-tags')
# Out:
# Index before upsert:
# {'dimension': 1024,
#  'index_fullness': 0.0,
#  'namespaces': {},
#  'total_vector_count': 0}
#
#
# {'id': 'Frame_1_3_1', 'values': [0.015716552734375, -0.0255889892578125, -0.03106689453125, -0.0576171875, 0.0249176025390625, -0.052764892578125, -0.0345458984375, 0.061431884765625, 0.060638427734375, -0.0167083740234375, 0.06182861328125, 0.02685546875, -0.02801513671875, -0.00725555419921875, -0.0404052734375, 0.0159912109375, -0.043914794921875, 0.0093841552734375, -0.002674102783203125, -0.036346435546875, 0.037200927734375, -0.005214691162109375, -0.0430908203125, -0.037109375, -0.0181884765625, -0.0081787109375, -0.030609130859375, -0.052886962890625, -0.007633209228515625, -0.0309295654296875, -0.00035119056701660156, 0.0309600830078125, -0.01384735107421875, -0.024688720703125, -0.015411376953125, -0.00206756591796875, 0.0201568603515625, 0.04156494140625, -0.0589599609375, -0.00542449951171875, -0.0092926025390625, 0.036895751953125, 0.00937652587890625, -0.01690673828125, 0.0019741058349609375, 0.0138702392578125, 0.048248291015625, 0.0193023681640625, -0.01068115234375, 0.00913238525390625, 0.02166748046875, 0.0024127960205078125, -0.0159912109375, -0.031341552734375, -0.0188140869140625, 0.0316162109375, -0.01947021484375, 0.0126190185546875, -0.0753
Please AVOID any discussion that is generic to many well-made marketing emails. 
Some examples of overly generic things to call outare things like "Clean Spacing", Mobile-Optimized", or "Professional". We can assume that all emails in our dataset are like this. 

Return the output as a json dictionary like so:
{
    "email_content_description": "...", # 1-2 sentences, up to 30 words.
    "tags": ["First Tag", "Second", ...], # 2-6 tags total. AVOID any tags related to the industry or product.
    
}
"""

# %%
b = create_image_tags_full_dataset(
    index_name='email-type',
    data_extraction_prompt=EMAIL_SITUATION_SYSTEM_PROMPT,  
    batch_size=80,
    tags_to_ignore='email_content_description'
)
# Out:
# 318 files to create
# batch starting with image 0, 2025-03-03 09:42:01.172809
# batch starting with image 80, 2025-03-03 09:42:28.605304
# batch starting with image 160, 2025-03-03 09:42:56.455664
# batch starting with image 240, 2025-03-03 09:43:20.134199
# Waiting for batch msgbatch_01Wzy12wS2GzGRkkNN9tfu1p
# Batch status: MessageBatch(id='msgbatch_01Wzy12wS2GzGRkkNN9tfu1p', archived_at=None, cancel_initiated_at=None, created_at=datetime.datetime(2025, 3, 3, 17, 42, 28, 449374, tzinfo=datetime.timezone.utc), ended_at=None, expires_at=datetime.datetime(2025, 3, 4, 17, 42, 28, 449374, tzinfo=datetime.timezone.utc), processing_status='in_progress', request_counts=MessageBatchRequestCounts(canceled=0, errored=0, expired=0, processing=80, succeeded=0), results_url=None, type='message_batch')
# Batch msgbatch_01Wzy12wS2GzGRkkNN9tfu1p still processing...
# Batch status: MessageBatch(id='msgbatch_01Wzy12wS2GzGRkkNN9tfu1p', archived_at=None, cancel_initiated_at=None, created_at=datetime.datetime(2025, 3, 3, 17, 42, 28, 449374, tzinfo=datetime.timezone.utc), ended_at=None, expires_at=datetime.datetime(2025, 3, 4, 17, 42, 28, 449374, tzinfo=datetime.timezone.utc), processing_status='in_progress', request_counts=MessageBatchRequestCounts(canceled=0, errored=0, expired=0, processing=80, succeeded=0), results_url=None, type='message_batch')
# Batch msgbatch_01Wzy12wS2GzGRkkNN9tfu1p still processing...
# Batch status: MessageBatch(id='msgbatch_01Wzy12wS2GzGRkkNN9tfu1p', archived_at=None, cancel_initiated_at=None, created_at=datetime.datetime(2025, 3, 3, 17, 42, 28, 449374, tzinfo=datetime.timezone.utc), ended_at=None, expires_at=datetime.datetime(2025, 3, 4, 17, 42, 28, 449374, tzinfo=datetime.timezone.utc), processing_status='in_progress', request_counts=MessageBatchRequestCounts(canceled=0, errored=0, expired=0, processing=80, succeeded=0), results_url=None, type='message_batch')
# Batch msgbatch_01Wzy12wS2GzGRkkNN9tfu1p still processing...
# Batch status: MessageBatch(id='msgbatch_01Wzy12wS2GzGRkkNN9tfu1p', archived_at=None, cancel_initiated_at=None, created_at=datetime.datetime(2025, 3, 3, 17, 42, 28, 449374, tzinfo=datetime.timezone.utc), ended_at=None, expires_at=datetime.datetime(2025, 3, 4, 17, 42, 28, 449374, tzinfo=datetime.timezone.utc), processing_status='in_progress', request_counts=MessageBatchRequestCounts(canceled=0, errored=0, expired=0, processing=80, succeeded=0), results_url=None, type='message_batch')
# Batch msgbatch_01Wzy12wS2GzGRkkNN9tfu1p still processing...
# Batch status: MessageBatch(id='msgbatch_01Wzy12wS2GzGRkkNN9tfu1p', archived_at=None, cancel_initiated_at=None, created_at=datetime.datetime(2025, 3, 3, 17, 42, 28, 449374, tzinfo=datetime.timezone.utc), ended_at=datetime.datetime(2025, 3, 3, 17, 44, 42, 623061, tzinfo=TzInfo(UTC)), expires_at=datetime.datetime(2025, 3, 4, 17, 42, 28, 449374, tzinfo=datetime.timezone.utc), processing_status='ended', request_counts=MessageBatchRequestCounts(canceled=0, errored=0, expired=0, processing=0, succeeded=80), results_url='https://api.anthropic.com/v1/messages/batches/msgbatch_01Wzy12wS2GzGRkkNN9tfu1p/results', type='message_batch')
# Batch msgbatch_01Wzy12wS2GzGRkkNN9tfu1p finished. Grabbing data.
# Waiting for batch msgbatch_0151hFVFKhHDtSzqLpdUVHBE
# Batch status: MessageBatch(id='msgbatch_0151hFVFKhHDtSzqLpdUVHBE', archived_at=None, cancel_initiated_at=None, created_at=datetime.datetime(2025, 3, 3, 17, 42, 56, 260812, tzinfo=datetime.timezone.utc), ended_at=datetime.datetime(2025, 3, 3, 17, 44, 11, 807185, tzinfo=TzInfo(UTC)), expires_at=datetime.datetime(2025, 3, 4, 17, 42, 56, 260812, tzinfo=datetime.timezone.utc), processing_status='ended', request_counts=MessageBatchRequestCounts(canceled=0, errored=0, expired=0, processing=0, succeeded=80), results_url='https://api.anthropic.com/v1/messages/batches/msgbatch_0151hFVFKhHDtSzqLpdUVHBE/results', type='message_batch')
# Batch msgbatch_0151hFVFKhHDtSzqLpdUVHBE finished. Grabbing data.
# Waiting for batch msgbatch_01TQStg3d7dhJecfkwcHWZHu
# Batch status: MessageBatch(id='msgbatch_01TQStg3d7dhJecfkwcHWZHu', archived_at=None, cancel_initiated_at=None, created_at=datetime.datetime(2025, 3, 3, 17, 43, 20, 158350, tzinfo=datetime.timezone.utc), ended_at=datetime.datetime(2025, 3, 3, 17, 44, 24, 97749, tzinfo=TzInfo(UTC)), expires_at=datetime.datetime(2025, 3, 4, 17, 43, 20, 158350, tzinfo=datetime.timezone.utc), processing_status='ended', request_counts=MessageBatchRequestCounts(canceled=0, errored=0, expired=0, processing=0, succeeded=80), results_url='https://api.anthropic.com/v1/messages/batches/msgbatch_01TQStg3d7dhJecfkwcHWZHu/results', type='message_batch')
# Batch msgbatch_01TQStg3d7dhJecfkwcHWZHu finished. Grabbing data.
# Waiting for batch msgbatch_01LeeSUMoZRoqiTfbnR5n5m2
# Batch status: MessageBatch(id='msgbatch_01LeeSUMoZRoqiTfbnR5n5m2', archived_at=None, cancel_initiated_at=None, created_at=datetime.datetime(2025, 3, 3, 17, 43, 45, 917823, tzinfo=datetime.timezone.utc), ended_at=None, expires_at=datetime.datetime(2025, 3, 4, 17, 43, 45, 917823, tzinfo=datetime.timezone.utc), processing_status='in_progress', request_counts=MessageBatchRequestCounts(canceled=0, errored=0, expired=0, processing=78, succeeded=0), results_url=None, type='message_batch')
# Batch msgbatch_01LeeSUMoZRoqiTfbnR5n5m2 still processing...
# Batch status: MessageBatch(id='msgbatch_01LeeSUMoZRoqiTfbnR5n5m2', archived_at=None, cancel_initiated_at=None, created_at=datetime.datetime(2025, 3, 3, 17, 43, 45, 917823, tzinfo=datetime.timezone.utc), ended_at=None, expires_at=datetime.datetime(2025, 3, 4, 17, 43, 45, 917823, tzinfo=datetime.timezone.utc), processing_status='in_progress', request_counts=MessageBatchRequestCounts(canceled=0, errored=0, expired=0, processing=78, succeeded=0), results_url=None, type='message_batch')
# Batch msgbatch_01LeeSUMoZRoqiTfbnR5n5m2 still processing...
# Batch status: MessageBatch(id='msgbatch_01LeeSUMoZRoqiTfbnR5n5m2', archived_at=None, cancel_initiated_at=None, created_at=datetime.datetime(2025, 3, 3, 17, 43, 45, 917823, tzinfo=datetime.timezone.utc), ended_at=None, expires_at=datetime.datetime(2025, 3, 4, 17, 43, 45, 917823, tzinfo=datetime.timezone.utc), processing_status='in_progress', request_counts=MessageBatchRequestCounts(canceled=0, errored=0, expired=0, processing=78, succeeded=0), results_url=None, type='message_batch')
# Batch msgbatch_01LeeSUMoZRoqiTfbnR5n5m2 still processing...
# Batch status: MessageBatch(id='msgbatch_01LeeSUMoZRoqiTfbnR5n5m2', archived_at=None, cancel_initiated_at=None, created_at=datetime.datetime(2025, 3, 3, 17, 43, 45, 917823, tzinfo=datetime.timezone.utc), ended_at=None, expires_at=datetime.datetime(2025, 3, 4, 17, 43, 45, 917823, tzinfo=datetime.timezone.utc), processing_status='in_progress', request_counts=MessageBatchRequestCounts(canceled=0, errored=0, expired=0, processing=78, succeeded=0), results_url=None, type='message_batch')
# Batch msgbatch_01LeeSUMoZRoqiTfbnR5n5m2 still processing...
# Batch status: MessageBatch(id='msgbatch_01LeeSUMoZRoqiTfbnR5n5m2', archived_at=None, cancel_initiated_at=None, created_at=datetime.datetime(2025, 3, 3, 17, 43, 45, 917823, tzinfo=datetime.timezone.utc), ended_at=datetime.datetime(2025, 3, 3, 17, 46, 9, 324490, tzinfo=TzInfo(UTC)), expires_at=datetime.datetime(2025, 3, 4, 17, 43, 45, 917823, tzinfo=datetime.timezone.utc), processing_status='ended', request_counts=MessageBatchRequestCounts(canceled=0, errored=0, expired=0, processing=0, succeeded=78), results_url='https://api.anthropic.com/v1/messages/batches/msgbatch_01LeeSUMoZRoqiTfbnR5n5m2/results', type='message_batch')
# Batch msgbatch_01LeeSUMoZRoqiTfbnR5n5m2 finished. Grabbing data.
# ---------------------------------------------------------------------------
# ForbiddenException                        Traceback (most recent call last)
# Cell In[3], line 8
#       1 b = create_image_tags_full_dataset(
#       2     index_name='email-situation',
#       3     data_extraction_prompt=EMAIL_SITUATION_SYSTEM_PROMPT,
#       4     batch_size=80,
#       5     tags_to_ignore='email_content_description'
#       6 )
# ----> 8 create_index('email-situation')
#       9 get_embeddings_and_upsert('email-situation')
#
# File ~/coding_projects/email_content_search/notebooks/../utlities/pinecone_index_utilities.py:49, in create_index(index_name)
#      46 spec = ServerlessSpec(cloud=cloud, region=region)
#      48 if index_name not in pc.list_indexes().names():
# ---> 49     pc.create_index(
#      50         name=index_name,
#      51         dimension=embeddings.dimension,
#      52         metric="cosine",
#      53         spec=spec
#      54     )
#      55     # Wait for index to be ready
#      56     while not pc.describe_index(index_name).status['ready']:
#
# File ~/coding_projects/email_content_search/.venv/lib/python3.13/site-packages/pinecone/control/pinecone.py:373, in Pinecone.create_index(self, name, dimension, spec, metric, timeout, deletion_protection)
#     370 else:
#     371     raise TypeError("spec must be of type dict, ServerlessSpec, or PodSpec")
# --> 373 api_instance.create_index(
#     374     create_index_request=CreateIndexRequest(
#     375         name=name,
#     376         dimension=dimension,
#     377         metric=metric,
#     378         spec=index_spec,
#     379         deletion_protection=dp,
#     380     )
#     381 )
#     383 def is_ready():
#     384     status = self._get_status(name)
#
# File ~/coding_projects/email_content_search/.venv/lib/python3.13/site-packages/pinecone/core/openapi/shared/api_client.py:821, in Endpoint.__call__(self, *args, **kwargs)
#     810 def __call__(self, *args, **kwargs):
#     811     """This method is invoked when endpoints are called
#     812     Example:
#     813
#    (...)
#     819
#     820     """
# --> 821     return self.callable(self, *args, **kwargs)
#
# File ~/coding_projects/email_content_search/.venv/lib/python3.13/site-packages/pinecone/core/openapi/control/api/manage_indexes_api.py:273, in ManageIndexesApi.__init__.<locals>.__create_index(self, create_index_request, **kwargs)
#     271 kwargs["_host_index"] = kwargs.get("_host_index")
#     272 kwargs["create_index_request"] = create_index_request
# --> 273 return self.call_with_http_info(**kwargs)
#
# File ~/coding_projects/email_content_search/.venv/lib/python3.13/site-packages/pinecone/core/openapi/shared/api_client.py:879, in Endpoint.call_with_http_info(self, **kwargs)
#     876     header_list = self.api_client.select_header_content_type(content_type_headers_list)
#     877     params["header"]["Content-Type"] = header_list
# --> 879 return self.api_client.call_api(
#     880     self.settings["endpoint_path"],
#     881     self.settings["http_method"],
#     882     params["path"],
#     883     params["query"],
#     884     params["header"],
#     885     body=params["body"],
#     886     post_params=params["form"],
#     887     files=params["file"],
#     888     response_type=self.settings["response_type"],
#     889     auth_settings=self.settings["auth"],
#     890     async_req=kwargs["async_req"],
#     891     async_threadpool_executor=kwargs.get("async_threadpool_executor", None),
#     892     _check_type=kwargs["_check_return_type"],
#     893     _return_http_data_only=kwargs["_return_http_data_only"],
#     894     _preload_content=kwargs["_preload_content"],
#     895     _request_timeout=kwargs["_request_timeout"],
#     896     _host=_host,
#     897     collection_formats=params["collection_format"],
#     898 )
#
# File ~/coding_projects/email_content_search/.venv/lib/python3.13/site-packages/pinecone/core/openapi/shared/api_client.py:431, in ApiClient.call_api(self, resource_path, method, path_params, query_params, header_params, body, post_params, files, response_type, auth_settings, async_req, async_threadpool_executor, _return_http_data_only, collection_formats, _preload_content, _request_timeout, _host, _check_type)
#     410     return self.threadpool_executor.submit(
#     411         self.__call_api,
#     412         resource_path,
#    (...)
#     427         _check_type,
#     428     )
#     430 if not async_req:
# --> 431     return self.__call_api(
#     432         resource_path,
#     433         method,
#     434         path_params,
#     435         query_params,
#     436         header_params,
#     437         body,
#     438         post_params,
#     439         files,
#     440         response_type,
#     441         auth_settings,
#     442         _return_http_data_only,
#     443         collection_formats,
#     444         _preload_content,
#     445         _request_timeout,
#     446         _host,
#     447         _check_type,
#     448     )
#     450 return self.pool.apply_async(
#     451     retry_api_call,
#     452     args=(
#    (...)
#     476     )
#     477 )
#
# File ~/coding_projects/email_content_search/.venv/lib/python3.13/site-packages/pinecone/core/openapi/shared/api_client.py:216, in ApiClient.__call_api(self, resource_path, method, path_params, query_params, header_params, body, post_params, files, response_type, auth_settings, _return_http_data_only, collection_formats, _preload_content, _request_timeout, _host, _check_type)
#     214 except PineconeApiException as e:
#     215     e.body = e.body.decode("utf-8")
# --> 216     raise e
#     218 self.last_response = response_data
#     220 return_data = response_data
#
# File ~/coding_projects/email_content_search/.venv/lib/python3.13/site-packages/pinecone/core/openapi/shared/api_client.py:204, in ApiClient.__call_api(self, resource_path, method, path_params, query_params, header_params, body, post_params, files, response_type, auth_settings, _return_http_data_only, collection_formats, _preload_content, _request_timeout, _host, _check_type)
#     200     url = _host + resource_path
#     202 try:
#     203     # perform request and return response
# --> 204     response_data = self.request(
#     205         method,
#     206         url,
#     207         query_params=query_params,
#     208         headers=header_params,
#     209         post_params=post_params,
#     210         body=body,
#     211         _preload_content=_preload_content,
#     212         _request_timeout=_request_timeout,
#     213     )
#     214 except PineconeApiException as e:
#     215     e.body = e.body.decode("utf-8")
#
# File ~/coding_projects/email_content_search/.venv/lib/python3.13/site-packages/pinecone/core/openapi/shared/api_client.py:518, in ApiClient.request(self, method, url, query_params, headers, post_params, body, _preload_content, _request_timeout)
#     508     return self.rest_client.OPTIONS(
#     509         url,
#     510         query_params=query_params,
#    (...)
#     515         body=body,
#     516     )
#     517 elif method == "POST":
# --> 518     return self.rest_client.POST(
#     519         url,
#     520         query_params=query_params,
#     521         headers=headers,
#     522         post_params=post_params,
#     523         _preload_content=_preload_content,
#     524         _request_timeout=_request_timeout,
#     525         body=body,
#     526     )
#     527 elif method == "PUT":
#     528     return self.rest_client.PUT(
#     529         url,
#     530         query_params=query_params,
#    (...)
#     535         body=body,
#     536     )
#
# File ~/coding_projects/email_content_search/.venv/lib/python3.13/site-packages/pinecone/core/openapi/shared/rest.py:345, in RESTClientObject.POST(self, url, headers, query_params, post_params, body, _preload_content, _request_timeout)
#     335 def POST(
#     336     self,
#     337     url,
#    (...)
#     343     _request_timeout=None,
#     344 ):
# --> 345     return self.request(
#     346         "POST",
#     347         url,
#     348         headers=headers,
#     349         query_params=query_params,
#     350         post_params=post_params,
#     351         _preload_content=_preload_content,
#     352         _request_timeout=_request_timeout,
#     353         body=body,
#     354     )
#
# File ~/coding_projects/email_content_search/.venv/lib/python3.13/site-packages/pinecone/core/openapi/shared/rest.py:271, in RESTClientObject.request(self, method, url, query_params, headers, body, post_params, _preload_content, _request_timeout)
#     268     raise UnauthorizedException(http_resp=r)
#     270 if r.status == 403:
# --> 271     raise ForbiddenException(http_resp=r)
#     273 if r.status == 404:
#     274     raise NotFoundException(http_resp=r)
#
# ForbiddenException: (403)
# Reason: Forbidden
# HTTP response headers: HTTPHeaderDict({'content-type': 'text/plain; charset=utf-8', 'access-control-allow-origin': '*', 'vary': 'origin,access-control-request-method,access-control-request-headers', 'access-control-expose-headers': '*', 'x-pinecone-api-version': '2024-07', 'X-Cloud-Trace-Context': 'be8189a939e8a4def5c8bbecea9e45f2', 'Date': 'Mon, 03 Mar 2025 17:46:25 GMT', 'Server': 'Google Frontend', 'Content-Length': '206', 'Via': '1.1 google', 'Alt-Svc': 'h3=":443"; ma=2592000,h3-29=":443"; ma=2592000'})
# HTTP response body: {"error":{"code":"FORBIDDEN","message":"Request failed. You've reached the max serverless indexes allowed in project Multimodal search (5). To add more serverless indexes, upgrade your plan."},"status":403}

# %%
 
create_index('email-type')
get_embeddings_and_upsert('email-type')
# Out:
# Index before upsert:
# {'dimension': 1024,
#  'index_fullness': 0.0,
#  'namespaces': {},
#  'total_vector_count': 0}
#
#
# Index after upsert:
# {'dimension': 1024,
#  'index_fullness': 0.0,
#  'namespaces': {},
#  'total_vector_count': 0}
